# %%
#import libraries
import json
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
with open('data/pakistan.json') as f:
    data = json.load(f)

data
# Out:
# {'lahore': {'food': [{'name': 'Butt Karahi',
#     'location': 'Lakshmi Chowk, Lahore'},
#    {'name': 'Phajja Siri Paye', 'location': 'Shah Alam Market, Lahore'},
#    {'name': 'Haveli Restaurant',
#     'location': 'Food Street, Fort Road, Lahore'}],
#   'hotels': [{'name': 'Avari Lahore', 'location': 'Mall Road, Lahore'},
#    {'name': 'Pearl Continental',
#     'location': 'Shahrah-e-Quaid-e-Azam, Lahore'}],
#   'places': [{'name': 'Badshahi Mosque', 'location': 'Walled City, Lahore'},
#    {'name': 'Lahore Fort', 'location': 'Fort Road, Lahore'}]},
#  'karachi': {'food': [{'name': 'Kolachi', 'location': 'Do Darya, Karachi'},
#    {'name': 'Cafe Flo', 'location': 'Clifton, Karachi'},
#    {'name': 'BBQ Tonight', 'location': 'Boat Basin, Karachi'}],
#   'hotels': [{'name': 'Marriott Hotel',
#     'location': 'Shahrah-e-Faisal, Karachi'},
#    {'name': 'Avari Towers', 'location': 'Fatima Jinnah Road, Karachi'}],
#   'places': [{'name': 'Clifton Beach', 'location': 'Clifton, Karachi'},
#    {'name': 'Frere Hall', 'location': 'Saddar, Karachi'}]},
#  'islamabad': {'food': [{'name': 'Monal', 'location': 'Pir Sohawa, Islamabad'},
#    {'name': 'Savour Foods', 'location': 'Blue Area, Islamabad'},
#    {'name': '1969 Restaurant', 'location': 'Garden Avenue, Islamabad'}],
#   'hotels': [{'name': 'Serena Hotel', 'location': 'Khaplu Road, Islamabad'},
#    {'name': 'Marriott Hotel', 'location': 'Agha Khan Road, Islamabad'}],
#   'places': [{'name': 'Faisal Mosque',
#     'location': 'Shah Faisal Ave, Islamabad'},
#    {'name': 'Daman-e-Koh', 'location': 'Margalla Hills, Islamabad'}]},
#  'peshawar': {'food': [{'name': 'Nisar Charsi Tikka',
#     'location': 'University Road, Peshawar'},
#    {'name': 'Chief Burgers', 'location': 'Saddar Road, Peshawar'}],
#   'hotels': [{'name': 'Pearl Continental',
#     'location': 'Khyber Road, Peshawar'},
#    {'name': "Shelton's Rezidor", 'location': 'University Town, Peshawar'}],
#   'places': [{'name': 'Qissa Khwani Bazaar', 'location': 'Old City, Peshawar'},
#    {'name': 'Bala Hisar Fort', 'location': 'G.T. Road, Peshawar'}]},
#  'quetta': {'food': [{'name': 'Usmania Restaurant',
#     'location': 'Jinnah Road, Quetta'},
#    {'name': 'Lehri Sajji House', 'location': 'Prince Road, Quetta'}],
#   'hotels': [{'name': 'Quetta Serena Hotel',
#     'location': 'Shahrah-e-Zarghoon, Quetta'}],
#   'places': [{'name': 'Hanna Lake', 'location': 'Urak Valley, Quetta'},
#    {'name': 'Ziarat Residency', 'location': 'Ziarat, Balochistan'}]},
#  'multan': {'food': [{'name': 'Shangrilla Cuisine',
#     'location': 'Cantt Area, Multan'},
#    {'name': 'Tasty BBQ', 'location': 'Boson Road, Multan'}],
#   'hotels': [{'name': 'Ramada Multan', 'location': 'Abdali Road, Multan'},
#    {'name': 'Hotel One', 'location': 'Old Bahawalpur Road, Multan'}],
#   'places': [{'name': 'Tomb of Shah Rukn-e-Alam',
#     'location': 'Qasim Bagh, Multan'},
#    {'name': 'Multan Fort', 'location': 'Fort Kohna, Multan'}]},
#  'faisalabad': {'food': [{'name': "Salt'n Pepper Village",
#     'location': 'Kohinoor City, Faisalabad'},
#    {'name': 'Al-Nakhal', 'location': 'Susan Road, Faisalabad'}],
#   'hotels': [{'name': 'Hotel One', 'location': 'D-Ground, Faisalabad'},
#    {'name': 'Grand Regent Hotel', 'location': 'Chen One Road, Faisalabad'}],
#   'places': [{'name': 'Clock Tower',
#     'location': 'Ghanta Ghar Chowk, Faisalabad'},
#    {'name': 'Lyallpur Museum', 'location': 'Mall Road, Faisalabad'}]}}

# %%
rows = []

for city, info in data.items():
    for category in ["food", "hotels", "places"]:
        for item in info.get(category, []):
            rows.append({
                "city": city,
                "category": category,
                "name": item["name"],
                "location": item["location"],
                "text": f"{item['name']} in {city} - {category} near {item['location']}"
            })

df = pd.DataFrame(rows)

df.to_csv("model/data.csv", index=False)

# %%
# TF-IDF Vectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df["text"])

# %%
# Example user query (simulate chat input)
user_query = "recommend me food in lahore"

# Transform query using same vectorizer
query_vec = vectorizer.transform([user_query])

# %%
# Compute cosine similarity
scores = cosine_similarity(query_vec, X).flatten()

# Get top 3 results
top_indices = scores.argsort()[-3:][::-1]

# Display results
df.iloc[top_indices]
# Out:
#      city category               name                        location  \
# 3  lahore   hotels       Avari Lahore               Mall Road, Lahore
# 2  lahore     food  Haveli Restaurant  Food Street, Fort Road, Lahore
# 6  lahore   places        Lahore Fort               Fort Road, Lahore
#
#                                                 text
# 3  Avari Lahore in lahore - hotels near Mall Road...
# 2  Haveli Restaurant in lahore - food near Food S...
# 6  Lahore Fort in lahore - places near Fort Road,...

# %%
def recommend(query, data_frame, vectorizer):
    query_vec = vectorizer.transform([query])
    scores = cosine_similarity(query_vec, X).flatten()
    top_indices = scores.argsort()[-3:][::-1]
    return data_frame.iloc[top_indices]

# Try it!
recommend("best places to visit in karachi", df, vectorizer)
# Out:
#        city category           name          location  \
# 13  karachi   places     Frere Hall   Saddar, Karachi
# 12  karachi   places  Clifton Beach  Clifton, Karachi
# 8   karachi     food       Cafe Flo  Clifton, Karachi
#
#                                                  text
# 13  Frere Hall in karachi - places near Saddar, Ka...
# 12  Clifton Beach in karachi - places near Clifton...
# 8    Cafe Flo in karachi - food near Clifton, Karachi

# %%
import os
import pickle

# Ensure the 'model' directory exists
os.makedirs("model", exist_ok=True)

# Save vectorizer
with open("model/vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

# Save data to CSV
df.to_csv("model/data.csv", index=False)
